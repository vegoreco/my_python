# %%
film = input("Добро пожаловать в кионтетатр \"Питон!\"\nУ нас действуют скидки:\nПри покупки билетов на завтра - скидка составит 5%\nПри покупки от 20 билетов - скидка составит 20%\nСкидки суммируются!\nВыберите фильм из доступных:\n1. Паразиты - от 250 руб.\n2. 1917 - от 250 руб.\n3. Соник в кино - от 350 руб.\nВведите номер фильма:")
if film == "1":
    date = input("Выберите дату сеанса:\n1.Сегодня\n2.Завтра\nВведите номер даты:")
    seans = input("Выберите сеанс из доступных:\n1. 12:00 - 250 руб.\n2. 16:00 - 350 руб.\n3. 20:00 - 450 руб. \nВведите номер сеанса:")
    if seans == "1":
        price = 250
    if seans == "2":
        price = 350
    if seans == "3":
        price = 450
if film == "2":
    date = input("Выберите дату сеанса:\n1.Сегодня\n2.Завтра\nВведите номер даты:")
    seans = input("Выберите сеанс из доступных:\n1. 12:00 - 250 руб.\n2. 16:00 - 350 руб.\n3. 20:00 - 450 руб. \nВведите номер сеанса:")
    if seans == "1":
        price = 250
    if seans == "2":
        price = 350
    if seans == "3":
        price = 350
if film == "3":
    date = input("Выберите дату сеанса:\n1.Сегодня\n2.Завтра\nВведите номер даты:")
    seans = input("Выберите сеанс из доступных:\n1. 12:00 - 250 руб.\n2. 16:00 - 350 руб.\n3. 20:00 - 450 руб. \nВведите номер сеанса:")
    if seans == "1":
        price = 350
    if seans == "2":
        price = 450
    if seans == "3":
        price = 450
amont = int(input("Введите количество билетов:"))
print("Стоимость вашего заказа составит:", price * amont)
if date == "2" and amont < 20:
    print("Ура! Вам доступна скидка 5%, стоимость вашего заказа с учетом скидки составит:", price * amont * 0.95)
if amont >= 20 and date != "2":
    print("Ура! Вам доступна скидка 20%, стоимость вашего заказа с учетом скидки составит:", price * amont * 0.8)
if amont >= 20 and date == "2":
    print("Ура! Вам доступны целых две скидки 5% и 20%, стоимость вашего заказа с учетом скидок составит:", price * amont * 0.95 * 0.8)
print("Приятного просмотра!")
# Out:
# Добро пожаловать в кионтетатр "Питон!"
# У нас действуют скидки:
# При покупки билетов на завтра - скидка составит 5%
# При покупки от 20 билетов - скидка составит 20%
# Скидки суммируются!
# Выберите фильм из доступных:
# 1. Паразиты - от 250 руб.
# 2. 1917 - от 250 руб.
# 3. Соник в кино - от 350 руб.
# Введите номер фильма: 2
# Выберите дату сеанса:
# 1.Сегодня
# 2.Завтра
# Введите номер даты: 2
# Выберите сеанс из доступных:
# 1. 12:00 - 250 руб.
# 2. 16:00 - 350 руб.
# 3. 20:00 - 450 руб.
# Введите номер сеанса: 3
# Введите количество билетов: 20
# Стоимость вашего заказа составит: 7000
# Ура! Вам доступны целых две скидки 5% и 20%, стоимость вашего заказа с учетом скидок составит: 5320.0
# Приятного просмотра!
